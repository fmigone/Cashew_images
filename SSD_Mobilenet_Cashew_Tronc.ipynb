# %% [markdown]
# <a href="https://colab.research.google.com/github/fmigone/Cashew_images/blob/master/SSD_Mobilenet_Cashew_Tronc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Note! For a most up to date version of this notebook, make sure you copy from:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1wTMIrJhYsQdq_u7ROOkf0Lu_fsX5Mu8a)

# %% [markdown]
# ## **Training MobileNetSSD Object Detection on a Custom Dataset SINDEV Cashew**

# %% [markdown]
# ## Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Install Specific Keras & Tensorflow Version + Tensorflow_addons

# %%
# !pip install tensorflow==1.14
# !pip install keras==2.2
# !pip install  tensorflow_addons
# Out:
# Collecting tensorflow==1.14
#   Downloading https://files.pythonhosted.org/packages/f4/28/96efba1a516cdacc2e2d6d081f699c001d414cc8ca3250e6d59ae657eb2b/tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3MB)
#      |████████████████████████████████| 109.3MB 102kB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.8.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.12.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.32.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.2.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (3.12.4)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 53.7MB/s
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 9.1MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.2)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.19.5)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 55.8MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.36.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.6.1->tensorflow==1.14) (54.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.3.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.7.4.3)
# Installing collected packages: tensorboard, keras-applications, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# Successfully installed keras-applications-1.0.8 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0
# Collecting keras==2.2
#   Downloading https://files.pythonhosted.org/packages/68/12/4cabc5c01451eb3b413d19ea151f36e33026fc0efb932bf51bcaf54acbf5/Keras-2.2.0-py2.py3-none-any.whl (300kB)
#      |████████████████████████████████| 307kB 16.5MB/s
# Collecting keras-applications==1.0.2
#   Downloading https://files.pythonhosted.org/packages/e2/60/c557075e586e968d7a9c314aa38c236b37cb3ee6b37e8d57152b1a5e0b47/Keras_Applications-1.0.2-py2.py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 9.7MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.2) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.2) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.2) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras==2.2) (2.10.0)
# Collecting keras-preprocessing==1.0.1
#   Downloading https://files.pythonhosted.org/packages/f8/33/275506afe1d96b221f66f95adba94d1b73f6b6087cfb6132a5655b6fe338/Keras_Preprocessing-1.0.1-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.2) (1.15.0)
# ERROR: tensorflow 1.14.0 has requirement keras-applications>=1.0.6, but you'll have keras-applications 1.0.2 which is incompatible.
# ERROR: tensorflow 1.14.0 has requirement keras-preprocessing>=1.0.5, but you'll have keras-preprocessing 1.0.1 which is incompatible.
# Installing collected packages: keras-applications, keras-preprocessing, keras
#   Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
#   Found existing installation: Keras-Preprocessing 1.1.2
#     Uninstalling Keras-Preprocessing-1.1.2:
#       Successfully uninstalled Keras-Preprocessing-1.1.2
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.2.0 keras-applications-1.0.2 keras-preprocessing-1.0.1
# Collecting tensorflow_addons
#   Downloading https://files.pythonhosted.org/packages/74/e3/56d2fe76f0bb7c88ed9b2a6a557e25e83e252aec08f13de34369cd850a0b/tensorflow_addons-0.12.1-cp37-cp37m-manylinux2010_x86_64.whl (703kB)
#      |████████████████████████████████| 706kB 19.5MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.12.1

# %% [markdown]
# ## Import Libraries

# %%
import os
import keras
import imgaug as ia
ia.seed(1)
# %matplotlib inline
#!pip install object-detection
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# imageio library will be used for image input/output
import imageio
import pandas as pd
import numpy as np
import re
import os
import glob
# this library is needed to read XML files for converting it into CSV
import xml.etree.ElementTree as ET
import shutil

# %% [markdown]
# ## Configs and Hyperparameters

# %%
# If you forked the repo, you can replace the link.
repo_url = 'https://github.com/roboflow-ai/tensorflow-object-detection-faster-rcnn'

# Number of training steps - 1000 will train very quickly, but more steps will increase accuracy.
num_steps = 20000  # 200000 to improve

# Number of evaluation steps.
num_eval_steps = 7500

MODELS_CONFIG = {
    'ssd_mobilenet_v2': {
        'model_name': 'ssd_mobilenet_v2_coco_2018_03_29',
        'pipeline_file': 'ssd_mobilenet_v2_coco.config',
        'batch_size': 12
    },
    'faster_rcnn_inception_v2': {
        'model_name': 'faster_rcnn_inception_v2_coco_2018_01_28',
        'pipeline_file': 'faster_rcnn_inception_v2_pets.config',
        'batch_size': 12
    },
    'rfcn_resnet101': {
        'model_name': 'rfcn_resnet101_coco_2018_01_28',
        'pipeline_file': 'rfcn_resnet101_pets.config',
        'batch_size': 8
    },    
}

# Pick the model you want to use
# Select a model in `MODELS_CONFIG`.
selected_model = 'ssd_mobilenet_v2'

# Name of the object detection model to use.
MODEL = MODELS_CONFIG[selected_model]['model_name']

# Name of the pipline file in tensorflow object detection API.
pipeline_file = MODELS_CONFIG[selected_model]['pipeline_file']

# Training batch size fits in Colabe's Tesla K80 GPU memory for selected model.
batch_size = MODELS_CONFIG[selected_model]['batch_size']

# %%
# use TF 1.x for Object Detection APIs as they are not ported to TF 2.0 yet
# %tensorflow_version 1.x
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %% [markdown]
# ## Clone the `tensorflow-object-detection` repository or your fork.

# %%
import os

# %cd /content

repo_dir_path = os.path.abspath(os.path.join('.', os.path.basename(repo_url)))

# !git clone {repo_url}
# %cd {repo_dir_path}
# !git pull
# Out:
# /content
# Cloning into 'tensorflow-object-detection-faster-rcnn'...
# remote: Enumerating objects: 885, done.
# remote: Total 885 (delta 0), reused 0 (delta 0), pack-reused 885
# Receiving objects: 100% (885/885), 24.83 MiB | 41.42 MiB/s, done.
# Resolving deltas: 100% (428/428), done.
# /content/tensorflow-object-detection-faster-rcnn
# Already up to date.

# %% [markdown]
# ## Install Tensorflow Object Detectin API

# %%
# %cd /content
# !git clone --quiet https://github.com/tensorflow/models.git

# !pip install tf_slim

# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk

# !pip install -q Cython contextlib2 pillow lxml matplotlib

# !pip install -q pycocotools

# !pip install lvis

# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.

import sys
sys.path.append("/content/models")

import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'
os.environ['PYTHONPATH'] += ":/content/models"

# !python object_detection/builders/model_builder_test.py
# Out:
# /content
# Collecting tf_slim
#   Downloading https://files.pythonhosted.org/packages/02/97/b0f4a64df018ca018cc035d44f2ef08f91e2e8aa67271f6f19633a015ff7/tf_slim-1.1.0-py2.py3-none-any.whl (352kB)
#      |████████████████████████████████| 358kB 18.6MB/s
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from tf_slim) (0.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.2.2->tf_slim) (1.15.0)
# Installing collected packages: tf-slim
# Successfully installed tf-slim-1.1.0
# Selecting previously unselected package python-bs4.
# (Reading database ... 160975 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../4-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../5-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../6-python-lxml_4.2.1-1ubuntu0.3_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.3) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../7-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../8-python-pil_5.1.0-1ubuntu0.4_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1ubuntu0.4) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-bs4 (4.6.0-1) ...
# Setting up python-lxml:amd64 (4.2.1-1ubuntu0.3) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.4) ...
# Setting up python-webencodings (0.5-2) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up python-html5lib (0.999999999-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting lvis
#   Downloading https://files.pythonhosted.org/packages/72/b6/1992240ab48310b5360bfdd1d53163f43bb97d90dc5dc723c67d41c38e78/lvis-0.5.3-py3-none-any.whl
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.7/dist-packages (from lvis) (1.19.5)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (2.8.1)
# Requirement already satisfied: Cython>=0.29.12 in /usr/local/lib/python3.7/dist-packages (from lvis) (0.29.22)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (1.3.1)
# Requirement already satisfied: pyparsing>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (2.4.7)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis) (4.1.2.30)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (0.10.0)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from lvis) (3.2.2)
# Installing collected packages: lvis
# Successfully installed lvis-0.5.3
# /content/models/research
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Importation des données

# %%
repo_url = 'https://github.com/Abubakr05/Cashew_images'

# %%
import os
# %cd /content
repo_dir_path = os.path.abspath(os.path.join('.', os.path.basename(repo_url)))
# !git clone {repo_url}
# %cd {repo_dir_path}
# !git pull
# Out:
# /content
# Cloning into 'Cashew_images'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8244 (delta 2), reused 0 (delta 0), pack-reused 8236
# Receiving objects: 100% (8244/8244), 2.05 GiB | 51.46 MiB/s, done.
# Resolving deltas: 100% (4391/4391), done.
# Checking out files: 100% (7364/7364), done.
# /content/Cashew_images
# Already up to date.

# %%
# %cd /content/tensorflow-object-detection-faster-rcnn/data
# Out:
# /content/tensorflow-object-detection-faster-rcnn/data

# %% [markdown]
# #### Reorgarnisation de l'espace de travail

# %%
# %cd /content/Cashew_images/data2/FEUILLES/
# !mkdir -p  "images"
# !mkdir -p  "annotations"
# !pwd
# Out:
# /content/Cashew_images/data2/FEUILLES
# /content/Cashew_images/data2/FEUILLES

# %%
# %cd /content/Cashew_images/data2/FEUILLES/images/
# !mkdir -p  "train"
# !mkdir -p  "test"
# Out:
# /content/Cashew_images/data2/FEUILLES/images

# %%
#combiner les différents dossiers train provenant du repos github en un seul dossier train
import shutil
import os

# %%
#deplacement des images du train
#dossier=["train1","train2","train3","train4","train5","train6"]
dossier=["train1","train2"]
for item in dossier:
	source = "/content/Cashew_images/data2/FEUILLES/"+item
	destination = "/content/Cashew_images/data2/FEUILLES/images/train/"

	files = os.listdir(source)

	for file in files:
		new_path = shutil.move(f"{source}/{file}", destination)
		#print(new_path)

# %%
#deplacement des images du test
dossier=["test"]
for item in dossier:
	source = "/content/Cashew_images/data2/FEUILLES/test"
	destination = "/content/Cashew_images/data2/FEUILLES/images/test/"

	files = os.listdir(source)

	for file in files:
		new_path = shutil.move(f"{source}/{file}", destination)
		#print(new_path)

# %% [markdown]
# #### Data Augmentation

# %%
from imgaug.augmentables.bbs import BoundingBox, BoundingBoxesOnImage
from imgaug import augmenters as iaa

# %%
#fonction pour convertir les fichiers XML en un seul fichier CSV
def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for member in root.findall('object'):
            value = (root.find('filename').text,
                     float(root.find('size')[0].text),
                     float(root.find('size')[1].text),
                     member[0].text,
                     float(member[4][0].text),
                     float(member[4][1].text),
                     float(member[4][2].text),
                     float(member[4][3].text)
                     )
            xml_list.append(value)
    column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df

# %%
#conversion des annotation xml en csv - creation d'un fichier csv contenant les annotations
#train 
labels_df_finale_last_train = xml_to_csv('/content/Cashew_images/data2/FEUILLES/images/train/')
labels_df_finale_last_train.to_csv(('/content/Cashew_images/data2/FEUILLES/labels_train_finales.csv'), index=None)
#test
labels_df_finale_last_test = xml_to_csv('/content/Cashew_images/data2/FEUILLES/images/test/')
labels_df_finale_last_train.to_csv(('/content/Cashew_images/data2/FEUILLES/labels_test_finales.csv'), index=None)

# %%
#fonctions utiles pour la data augmentation à l'aide d'Image Aug
def bbs_obj_to_df(bbs_object):
#     convert BoundingBoxesOnImage object into array
    bbs_array = bbs_object.to_xyxy_array()
#     convert array into a DataFrame ['xmin', 'ymin', 'xmax', 'ymax'] columns
    df_bbs = pd.DataFrame(bbs_array, columns=['xmin', 'ymin', 'xmax', 'ymax'])
    return df_bbs

def resize_imgaug(df, images_path, aug_images_path, image_prefix):
    # create data frame which we're going to populate with augmented image info
    aug_bbs_xy = pd.DataFrame(columns=
                              ['filename','width','height','class', 'xmin', 'ymin', 'xmax', 'ymax']
                             )
    grouped = df.groupby('filename')    

    for filename in df['filename'].unique():
    #   Get separate data frame grouped by file name
        group_df = grouped.get_group(filename)
        group_df = group_df.reset_index()
        group_df = group_df.drop(['index'], axis=1)

    #   If image height is greater than or equal to image width 
    #   AND greater than 600px perform resizing augmentation shrinking image height to 600px.
        if group_df['height'].unique()[0] >= group_df['width'].unique()[0] and group_df['height'].unique()[0] > 600:
        #   read the image
            image = imageio.imread(images_path+filename)
        #   get bounding boxes coordinates and write into array        
            bb_array = group_df.drop(['filename', 'width', 'height', 'class'], axis=1).values
        #   pass the array of bounding boxes coordinates to the imgaug library
            bbs = BoundingBoxesOnImage.from_xyxy_array(bb_array, shape=image.shape)
        #   apply augmentation on image and on the bounding boxes
            image_aug, bbs_aug = height_resize(image=image, bounding_boxes=bbs)
        #   write augmented image to a file
            imageio.imwrite(aug_images_path+image_prefix+filename, image_aug)  
        #   create a data frame with augmented values of image width and height
            info_df = group_df.drop(['xmin', 'ymin', 'xmax', 'ymax'], axis=1)        
            for index, _ in info_df.iterrows():
                info_df.at[index, 'width'] = image_aug.shape[1]
                info_df.at[index, 'height'] = image_aug.shape[0]
        #   rename filenames by adding the predifined prefix
            info_df['filename'] = info_df['filename'].apply(lambda x: image_prefix+x)
        #   create a data frame with augmented bounding boxes coordinates using the function we created earlier
            bbs_df = bbs_obj_to_df(bbs_aug)
        #   concat all new augmented info into new data frame
            aug_df = pd.concat([info_df, bbs_df], axis=1)
        #   append rows to aug_bbs_xy data frame
            aug_bbs_xy = pd.concat([aug_bbs_xy, aug_df])

    #   if image width is greater than image height 
    #   AND greater than 600px perform resizing augmentation shrinking image width to 600px
        elif group_df['width'].unique()[0] > group_df['height'].unique()[0] and group_df['width'].unique()[0] > 600:
        #   read the image
            image = imageio.imread(images_path+filename)
        #   get bounding boxes coordinates and write into array        
            bb_array = group_df.drop(['filename', 'width', 'height', 'class'], axis=1).values
        #   pass the array of bounding boxes coordinates to the imgaug library
            bbs = BoundingBoxesOnImage.from_xyxy_array(bb_array, shape=image.shape)
        #   apply augmentation on image and on the bounding boxes
            image_aug, bbs_aug = width_resize(image=image, bounding_boxes=bbs)
        #   write augmented image to a file
            imageio.imwrite(aug_images_path+image_prefix+filename, image_aug)  
        #   create a data frame with augmented values of image width and height
            info_df = group_df.drop(['xmin', 'ymin', 'xmax', 'ymax'], axis=1)        
            for index, _ in info_df.iterrows():
                info_df.at[index, 'width'] = image_aug.shape[1]
                info_df.at[index, 'height'] = image_aug.shape[0]
        #   rename filenames by adding the predifined prefix
            info_df['filename'] = info_df['filename'].apply(lambda x: image_prefix+x)
        #   create a data frame with augmented bounding boxes coordinates using the function we created earlier
            bbs_df = bbs_obj_to_df(bbs_aug)
        #   concat all new augmented info into new data frame
            aug_df = pd.concat([info_df, bbs_df], axis=1)
        #   append rows to aug_bbs_xy data frame
            aug_bbs_xy = pd.concat([aug_bbs_xy, aug_df])

    #     append image info without any changes if it's height and width are both less than 600px 
        else:
            aug_bbs_xy = pd.concat([aug_bbs_xy, group_df])
    # return dataframe with updated images and bounding boxes annotations 
    aug_bbs_xy = aug_bbs_xy.reset_index()
    aug_bbs_xy = aug_bbs_xy.drop(['index'], axis=1)
    return aug_bbs_xy

# %%
#fonctions utiles pour la data augmentation à l'aide d'Image Aug
def image_aug(df, images_path, aug_images_path, image_prefix, augmentor):
    # create data frame which we're going to populate with augmented image info
    aug_bbs_xy = pd.DataFrame(columns=
                              ['filename','width','height','class', 'xmin', 'ymin', 'xmax', 'ymax']
                             )
    grouped = df.groupby('filename')
    
    for filename in df['filename'].unique():
    #   get separate data frame grouped by file name
        group_df = grouped.get_group(filename)
        group_df = group_df.reset_index()
        group_df = group_df.drop(['index'], axis=1)   
    #   read the image
        image = imageio.imread(images_path+filename)
    #   get bounding boxes coordinates and write into array        
        bb_array = group_df.drop(['filename', 'width', 'height', 'class'], axis=1).values
    #   pass the array of bounding boxes coordinates to the imgaug library
        bbs = BoundingBoxesOnImage.from_xyxy_array(bb_array, shape=image.shape)
    #   apply augmentation on image and on the bounding boxes
        image_aug, bbs_aug = augmentor(image=image, bounding_boxes=bbs)
    #   disregard bounding boxes which have fallen out of image pane    
        bbs_aug = bbs_aug.remove_out_of_image()
    #   clip bounding boxes which are partially outside of image pane
        bbs_aug = bbs_aug.clip_out_of_image()
        
    #   don't perform any actions with the image if there are no bounding boxes left in it    
        if re.findall('Image...', str(bbs_aug)) == ['Image([]']:
            pass
        
    #   otherwise continue
        else:
        #   write augmented image to a file
            try:
                imageio.imwrite(aug_images_path+image_prefix+filename, image_aug)
            except:
                pass
        #   create a data frame with augmented values of image width and height
            info_df = group_df.drop(['xmin', 'ymin', 'xmax', 'ymax'], axis=1)    
            for index, _ in info_df.iterrows():
                info_df.at[index, 'width'] = image_aug.shape[1]
                info_df.at[index, 'height'] = image_aug.shape[0]
        #   rename filenames by adding the predifined prefix
            info_df['filename'] = info_df['filename'].apply(lambda x: image_prefix+x)
        #   create a data frame with augmented bounding boxes coordinates using the function we created earlier
            bbs_df = bbs_obj_to_df(bbs_aug)
        #   concat all new augmented info into new data frame
            aug_df = pd.concat([info_df, bbs_df], axis=1)
        #   append rows to aug_bbs_xy data frame
            aug_bbs_xy = pd.concat([aug_bbs_xy, aug_df])            
    
    # return dataframe with updated images and bounding boxes annotations 
    aug_bbs_xy = aug_bbs_xy.reset_index()
    aug_bbs_xy = aug_bbs_xy.drop(['index'], axis=1)
    return aug_bbs_xy

# %%
#Sequence d'augmentation - elle définit quelle opération sera réalisée dans le cadre de l'augmentation
aug = iaa.Sequential([
    iaa.Affine(rotate=(-10,10)),
    iaa.AdditiveGaussianNoise(scale=(0.05*255, 0.05*255)),
    iaa.Multiply(1.25)
])

# %%
#definition du dossier des données d'images initiales
image_init_train = '/content/Cashew_images/data2/FEUILLES/images/train/'

# %%
## Realisation de l'augmentation pour les données train
augmented_images_df_train = image_aug(labels_df_finale_last_train, image_init_train, image_init_train, 'aug1_', aug)

# %%
#definition du dossier des données d'images initiales
image_init_test = '/content/Cashew_images/data2/FEUILLES/images/test/'

# %%
## Realisation de l'augmentation pour les données train
augmented_images_df_test = image_aug(labels_df_finale_last_test, image_init_test, image_init_test, 'aug1_', aug)

# %%
#on crée une fonction true_name pour récupérer le nom des images sans l'extension ".jpg" dans le but de faire les fichiers d'annotations au format yolo plus tard
def true_name(f):
  return f.split('.jpg')[0]

# %%
data_csv_train = pd.concat([augmented_images_df_train,labels_df_finale_last_train])
data_csv_test = pd.concat([augmented_images_df_test,labels_df_finale_last_test])

# %%
data_csv_train['name'] = data_csv_train['filename'].apply (lambda row: true_name(row))
data_csv_test['name'] = data_csv_test['filename'].apply (lambda row: true_name(row))

# %%
data_csv_train.dropna(subset = ["xmin"], inplace=True)
data_csv_test.dropna(subset = ["xmin"], inplace=True)

# %%
data_csv_train.drop(data_csv_train[data_csv_train.filename == 'R_10_02-47-82-45_OP4_11PhotoDegat__.jpg'].index, inplace=True)

# %%
data_csv_train.to_csv(('/content/Cashew_images/data2/FEUILLES/images/data_csv_train.csv'), index=None)
data_csv_test.to_csv(('/content/Cashew_images/data2/FEUILLES/images/data_csv_test.csv'), index=None)

# %%
####  Conversion des annotations CSV en TFRecord
#### May help : https://stackoverflow.com/questions/52870674/how-to-fix-missing-files-or-folder-error-file-generate-tfrecord-py-line-110

# %% [markdown]
# #### Generate TFRecord

# %%
# %cd '/content/Cashew_images/data2/FEUILLES/images/train'
# !python '/content/Cashew_images/generate_tfrecord.py' -csv_input='/content/Cashew_images/data2/FEUILLES/images/data_csv_train.csv'  --output_path='/content/Cashew_images/data2/FEUILLES/train.record' --label_map='/content/Cashew_images/labelmap/cashew_label_map_feuilles.pbtxt'
# Out:
# /content/Cashew_images/data2/FEUILLES/images/train
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Traceback (most recent call last):
#   File "/content/Cashew_images/generate_tfrecord.py", line 134, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 300, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "/content/Cashew_images/generate_tfrecord.py", line 125, in main
#     tf_example = create_tf_example(group, path, label_map)
#   File "/content/Cashew_images/generate_tfrecord.py", line 79, in create_tf_example
#     row["class"], label_map
# AssertionError: class label: `Apate terebrans` not found in label_map: {'Anthracnose': 1, 'Carence minérale': 2, 'Dessèchement des bourgeons': 3, 'Die-black': 4, 'Dysdercus wolkerii': 5, 'Oidium': 6}

# %%
# %cd '/content/Cashew_images/data2/FEUILLES/images/test'
# !python '/content/Cashew_images/generate_tfrecord.py' -csv_input='/content/Cashew_images/data2/FEUILLES/images/data_csv_test.csv'  --output_path='/content/Cashew_images/data2/FEUILLES/test.record' --label_map='/content/Cashew_images/labelmap/cashew_label_map_feuilles.pbtxt'
# Out:
# /content/Cashew_images/data2/FEUILLES/images/test
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Traceback (most recent call last):
#   File "/content/Cashew_images/generate_tfrecord.py", line 134, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 300, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "/content/Cashew_images/generate_tfrecord.py", line 125, in main
#     tf_example = create_tf_example(group, path, label_map)
#   File "/content/Cashew_images/generate_tfrecord.py", line 79, in create_tf_example
#     row["class"], label_map
# AssertionError: class label: `Pestalotiose` not found in label_map: {'Anthracnose': 1, 'Carence minérale': 2, 'Dessèchement des bourgeons': 3, 'Die-black': 4, 'Dysdercus wolkerii': 5, 'Oidium': 6}

# %%
#recupération de la liste des éléments des classes
# %cd '/content/Cashew_images/data'
import csv
from tqdm import tqdm
import pandas as pd
classes_names = []
data = pd.read_excel('/content/Cashew_images/class.xlsx',index_col=None)
classes_names = data['label'].tolist()
# Out:
# /content/Cashew_images/data

# %%
# training set
# %ls train
# Out:
# ls: cannot access 'train': No such file or directory

# %%
# test set
# %ls test
# Out:
# R_10_02-47-82-45_OP4_11PhotoDegat__.jpg
# R_10_02-47-82-45_OP4_11PhotoDegat__.xml
# R_10_14-01-55-50_OP4_11PhotoDegat__.jpg
# R_10_14-01-55-50_OP4_11PhotoDegat__.xml
# R_10_14-24-72-58_OP4_21PhotoEtatsante___5.jpg
# R_10_14-24-72-58_OP4_21PhotoEtatsante___5.xml
# R_10_17-84-32-53_OP4_21PhotoEtatsante___5.jpg
# R_10_17-84-32-53_OP4_21PhotoEtatsante___5.xml
# R_1_01-96-20-37_OP4_11PhotoDegat__.jpg
# R_1_01-96-20-37_OP4_11PhotoDegat__.xml
# R_1_01-96-20-37_OP4_15PhotoEltParcel__.jpg
# R_1_01-96-20-37_OP4_15PhotoEltParcel__.xml
# R_10_31-32-53-78_OP4_21PhotoEtatsante___2.jpg
# R_10_31-32-53-78_OP4_21PhotoEtatsante___2.xml
# R_10_34-67-32-35_OP4_21PhotoEtatsante___2.jpg
# R_10_34-67-32-35_OP4_21PhotoEtatsante___2.xml
# R_10_52-34-47-31_OP4_21PhotoEtatsante___3.jpg
# R_10_52-34-47-31_OP4_21PhotoEtatsante___3.xml
# R_10_62-96-19-48_OP4_21PhotoEtatsante___2.jpg
# R_10_62-96-19-48_OP4_21PhotoEtatsante___2.xml
# R_10_63-73-88-27_OP4_11PhotoDegat__.jpg
# R_10_63-73-88-27_OP4_11PhotoDegat__.xml
# R_10_64-73-68-46_OP4_21PhotoEtatsante___3.jpg
# R_10_64-73-68-46_OP4_21PhotoEtatsante___3.xml
# R_10_67-30-25-39_OP4_19PhotoEtatSante__.jpg
# R_10_67-30-25-39_OP4_19PhotoEtatSante__.xml
# R_10_76-56-05-16_OP4_21PhotoEtatsante___2.jpg
# R_10_76-56-05-16_OP4_21PhotoEtatsante___2.xml
# R_10_84-55-55-54_OP4_21PhotoEtatsante___1.jpg
# R_10_84-55-55-54_OP4_21PhotoEtatsante___1.xml
# R_10_86-45-80-19_OP4_21PhotoEtatsante___3.jpg
# R_10_86-45-80-19_OP4_21PhotoEtatsante___3.xml
# R_10_93-54-72-67_OP4_21PhotoEtatsante___3.jpg
# R_10_93-54-72-67_OP4_21PhotoEtatsante___3.xml
# R_11_03-90-92-48_OP4_21PhotoEtatsante___1.jpg
# R_11_03-90-92-48_OP4_21PhotoEtatsante___1.xml
# R_1_11-10-63-82_OP4_11PhotoDegat__.jpg
# R_1_11-10-63-82_OP4_11PhotoDegat__.xml
# R_11_17-60-16-45_OP4_21PhotoEtatsante___3.jpg
# R_11_17-60-16-45_OP4_21PhotoEtatsante___3.xml
# R_11_18-97-10-70_OP4_21PhotoEtatsante___3.jpg
# R_11_18-97-10-70_OP4_21PhotoEtatsante___3.xml
# R_11_36-37-08-34_OP4_21PhotoEtatsante___4.jpg
# R_11_36-37-08-34_OP4_21PhotoEtatsante___4.xml
# R_11_36-38-77-99_OP4_21PhotoEtatsante___4.jpg
# R_11_36-38-77-99_OP4_21PhotoEtatsante___4.xml
# R_11_39-38-33-36_OP4_21PhotoEtatsante___3.jpg
# R_11_39-38-33-36_OP4_21PhotoEtatsante___3.xml
# R_11_41-76-86-63_OP4_21PhotoEtatsante___3.jpg
# R_11_41-76-86-63_OP4_21PhotoEtatsante___3.xml
# R_1_14-73-42-32_OP4_21PhotoEtatsante___2.jpg
# R_1_14-73-42-32_OP4_21PhotoEtatsante___2.xml
# R_11_55-34-11-83_OP4_21PhotoEtatsante___1.jpg
# R_11_55-34-11-83_OP4_21PhotoEtatsante___1.xml
# R_1_16-14-20-01_OP4_21PhotoEtatsante___1.jpg
# R_1_16-14-20-01_OP4_21PhotoEtatsante___1.xml
# R_1_16-14-20-01_OP4_21PhotoEtatsante___4.jpg
# R_1_16-14-20-01_OP4_21PhotoEtatsante___4.xml
# R_1_17-21-79-48_OP4_21PhotoEtatsante___3.jpg
# R_1_17-21-79-48_OP4_21PhotoEtatsante___3.xml
# R_11_73-71-37-70_OP4_21PhotoEtatsante___1.jpg
# R_11_73-71-37-70_OP4_21PhotoEtatsante___1.xml
# R_11_74-20-57-66_OP4_21PhotoEtatsante___4.jpg
# R_11_74-20-57-66_OP4_21PhotoEtatsante___4.xml
# R_12_03-20-60-84_OP4_21PhotoEtatsante___4.jpg
# R_12_03-20-60-84_OP4_21PhotoEtatsante___4.xml
# R_12_03-20-60-84_OP4_21PhotoEtatsante___5.jpg
# R_12_03-20-60-84_OP4_21PhotoEtatsante___5.xml
# R_12_03-55-10-86_OP4_21PhotoEtatsante___5.jpg
# R_12_03-55-10-86_OP4_21PhotoEtatsante___5.xml
# R_1_20-46-24-51_OP4_21PhotoEtatsante___3.jpg
# R_1_20-46-24-51_OP4_21PhotoEtatsante___3.xml
# R_12_05-76-52-02_OP4_21PhotoEtatsante___3.jpg
# R_12_05-76-52-02_OP4_21PhotoEtatsante___3.xml
# R_12_06-21-39-32_OP4_21PhotoEtatsante___1.jpg
# R_12_06-21-39-32_OP4_21PhotoEtatsante___1.xml
# R_12_11-04-45-88_OP4_21PhotoEtatsante___2.jpg
# R_12_11-04-45-88_OP4_21PhotoEtatsante___2.xml
# R_12_14-45-71-22_OP4_21PhotoEtatsante___5.jpg
# R_12_14-45-71-22_OP4_21PhotoEtatsante___5.xml
# R_12_20-13-46-86_OP4_11PhotoDegat__.jpg
# R_12_20-13-46-86_OP4_11PhotoDegat__.xml
# R_12_28-93-87-54_OP4_21PhotoEtatsante___3.jpg
# R_12_28-93-87-54_OP4_21PhotoEtatsante___3.xml
# R_12_28-93-87-54_OP4_21PhotoEtatsante___4.jpg
# R_12_28-93-87-54_OP4_21PhotoEtatsante___4.xml
# R_12_34-20-68-64_OP4_21PhotoEtatsante___4.jpg
# R_12_34-20-68-64_OP4_21PhotoEtatsante___4.xml
# R_12_37-89-44-72_OP4_21PhotoEtatsante___4.jpg
# R_12_37-89-44-72_OP4_21PhotoEtatsante___4.xml
# R_12_46-49-39-33_OP4_19PhotoEtatSante__.jpg
# R_12_46-49-39-33_OP4_19PhotoEtatSante__.xml
# R_1_26-66-74-09_OP4_21PhotoEtatsante___5.jpg
# R_1_26-66-74-09_OP4_21PhotoEtatsante___5.xml
# R_1_28-15-24-31_OP4_15PhotoEltParcel__.jpg
# R_1_28-15-24-31_OP4_15PhotoEltParcel__.xml
# R_1_30-29-99-13_OP4_21PhotoEtatsante___4.jpg
# R_1_30-29-99-13_OP4_21PhotoEtatsante___4.xml
# R_1_30-75-52-96_OP4_11PhotoDegat__.jpg
# R_1_30-75-52-96_OP4_11PhotoDegat__.xml
# R_13_09-04-98-30_OP4_21PhotoEtatsante___1.jpg
# R_13_09-04-98-30_OP4_21PhotoEtatsante___1.xml
# R_1_34-33-65-81_OP4_11PhotoDegat__.jpg
# R_1_34-33-65-81_OP4_11PhotoDegat__.xml
# R_1_34-33-65-81_OP4_21PhotoEtatsante___1.jpg
# R_1_34-33-65-81_OP4_21PhotoEtatsante___1.xml
# R_13_47-32-53-90_OP4_21PhotoEtatsante___2.jpg
# R_13_47-32-53-90_OP4_21PhotoEtatsante___2.xml
# R_13_63-35-26-86_OP4_21PhotoEtatsante___3.jpg
# R_13_63-35-26-86_OP4_21PhotoEtatsante___3.xml
# R_13_70-18-61-16_OP4_21PhotoEtatsante___5.jpg
# R_13_70-18-61-16_OP4_21PhotoEtatsante___5.xml
# R_1_37-43-36-86_OP4_21PhotoEtatsante___5.jpg
# R_1_37-43-36-86_OP4_21PhotoEtatsante___5.xml
# R_13_79-68-57-70_OP4_21PhotoEtatsante___4.jpg
# R_13_79-68-57-70_OP4_21PhotoEtatsante___4.xml
# R_13_93-26-58-58_OP4_21PhotoEtatsante___1.jpg
# R_13_93-26-58-58_OP4_21PhotoEtatsante___1.xml
# R_14_12-46-72-73_OP4_21PhotoEtatsante___5.jpg
# R_14_12-46-72-73_OP4_21PhotoEtatsante___5.xml
# R_14_52-18-38-09_OP4_21PhotoEtatsante___2.jpg
# R_14_52-18-38-09_OP4_21PhotoEtatsante___2.xml
# R_1_45-38-83-48_OP4_19PhotoEtatSante__.jpg
# R_1_45-38-83-48_OP4_19PhotoEtatSante__.xml
# R_1_45-38-83-48_OP4_21PhotoEtatsante___5.jpg
# R_1_45-38-83-48_OP4_21PhotoEtatsante___5.xml
# R_14_86-64-66-29_OP4_21PhotoEtatsante___5.jpg
# R_14_86-64-66-29_OP4_21PhotoEtatsante___5.xml
# R_1_50-06-68-02_OP4_11PhotoDegat__.jpg
# R_1_50-06-68-02_OP4_11PhotoDegat__.xml
# R_15_49-31-40-41_OP4_21PhotoEtatsante___2.jpg
# R_15_49-31-40-41_OP4_21PhotoEtatsante___2.xml
# R_15_65-42-86-20_OP4_21PhotoEtatsante___4.jpg
# R_15_65-42-86-20_OP4_21PhotoEtatsante___4.xml
# R_15_76-99-01-16_OP4_21PhotoEtatsante___4.jpg
# R_15_76-99-01-16_OP4_21PhotoEtatsante___4.xml
# R_16_16-24-69-49_OP4_21PhotoEtatsante___2.jpg
# R_16_16-24-69-49_OP4_21PhotoEtatsante___2.xml
# R_16_19-36-59-13_OP4_21PhotoEtatsante___5.jpg
# R_16_19-36-59-13_OP4_21PhotoEtatsante___5.xml
# R_16_21-62-32-52_OP4_21PhotoEtatsante___5.jpg
# R_16_21-62-32-52_OP4_21PhotoEtatsante___5.xml
# R_1_69-29-45-87_OP4_21PhotoEtatsante___5.jpg
# R_1_69-29-45-87_OP4_21PhotoEtatsante___5.xml
# R_17_04-30-46-60_OP4_21PhotoEtatsante___4.jpg
# R_17_04-30-46-60_OP4_21PhotoEtatsante___4.xml
# R_17_18-57-16-29_OP4_19PhotoEtatSante__.jpg
# R_17_18-57-16-29_OP4_19PhotoEtatSante__.xml
# R_17_32-67-80-26_OP4_21PhotoEtatsante___4.jpg
# R_17_32-67-80-26_OP4_21PhotoEtatsante___4.xml
# R_17_33-55-23-96_OP4_21PhotoEtatsante___3.jpg
# R_17_33-55-23-96_OP4_21PhotoEtatsante___3.xml
# R_17_36-66-92-87_OP4_21PhotoEtatsante___2.jpg
# R_17_36-66-92-87_OP4_21PhotoEtatsante___2.xml
# R_17_38-88-52-25_OP4_21PhotoEtatsante___5.jpg
# R_17_38-88-52-25_OP4_21PhotoEtatsante___5.xml
# R_17_39-50-74-77_OP4_21PhotoEtatsante___1.jpg
# R_17_39-50-74-77_OP4_21PhotoEtatsante___1.xml
# R_17_42-38-11-12_OP4_21PhotoEtatsante___3.jpg
# R_17_42-38-11-12_OP4_21PhotoEtatsante___3.xml
# R_1_74-62-02-10_OP4_21PhotoEtatsante___5.jpg
# R_1_74-62-02-10_OP4_21PhotoEtatsante___5.xml
# R_17_46-75-02-81_OP4_21PhotoEtatsante___2.jpg
# R_17_46-75-02-81_OP4_21PhotoEtatsante___2.xml
# R_17_53-07-37-83_OP4_21PhotoEtatsante___5.jpg
# R_17_53-07-37-83_OP4_21PhotoEtatsante___5.xml
# R_17_57-07-42-06_OP4_21PhotoEtatsante___4.jpg
# R_17_57-07-42-06_OP4_21PhotoEtatsante___4.xml
# R_17_64-13-46-49_OP4_21PhotoEtatsante___5.jpg
# R_17_64-13-46-49_OP4_21PhotoEtatsante___5.xml
# R_17_64-32-18-39_OP4_21PhotoEtatsante___2.jpg
# R_17_64-32-18-39_OP4_21PhotoEtatsante___2.xml
# R_17_71-76-89-93_OP4_21PhotoEtatsante___4.jpg
# R_17_71-76-89-93_OP4_21PhotoEtatsante___4.xml
# R_17_93-90-25-06_OP4_21PhotoEtatsante___5.jpg
# R_17_93-90-25-06_OP4_21PhotoEtatsante___5.xml
# R_17_97-15-28-41_OP4_21PhotoEtatsante___2.jpg
# R_17_97-15-28-41_OP4_21PhotoEtatsante___2.xml
# R_18_06-62-30-67_OP4_21PhotoEtatsante___3.jpg
# R_18_06-62-30-67_OP4_21PhotoEtatsante___3.xml
# R_1_82-97-53-23_OP4_11PhotoDegat__.jpg
# R_1_82-97-53-23_OP4_11PhotoDegat__.xml
# R_1_86-32-66-85_OP4_21PhotoEtatsante___1.jpg
# R_1_86-32-66-85_OP4_21PhotoEtatsante___1.xml
# R_18_72-15-43-03_OP4_21PhotoEtatsante___2.jpg
# R_18_72-15-43-03_OP4_21PhotoEtatsante___2.xml
# R_18_76-39-64-84_OP4_11PhotoDegat__.jpg
# R_18_76-39-64-84_OP4_11PhotoDegat__.xml
# R_1_89-45-17-43_OP4_21PhotoEtatsante___4.jpg
# R_1_89-45-17-43_OP4_21PhotoEtatsante___4.xml
# R_1_90-77-08-08_OP4_21PhotoEtatsante___2.jpg
# R_1_90-77-08-08_OP4_21PhotoEtatsante___2.xml
# R_19_31-58-97-61_OP4_21PhotoEtatsante___2.jpg
# R_19_31-58-97-61_OP4_21PhotoEtatsante___2.xml
# R_1_93-23-21-22_OP4_11PhotoDegat__.jpg
# R_1_93-23-21-22_OP4_11PhotoDegat__.xml
# R_1_93-32-69-90_OP4_15PhotoEltParcel__.jpg
# R_1_93-32-69-90_OP4_15PhotoEltParcel__.xml
# R_1_93-32-69-90_OP4_21PhotoEtatsante___2.jpg
# R_1_93-32-69-90_OP4_21PhotoEtatsante___2.xml
# R_19_50-47-57-76_OP4_21PhotoEtatsante___1.jpg
# R_19_50-47-57-76_OP4_21PhotoEtatsante___1.xml
# R_1_95-08-90-47_OP4_19PhotoEtatSante__.jpg
# R_1_95-08-90-47_OP4_19PhotoEtatSante__.xml
# R_19_51-36-06-18_OP4_21PhotoEtatsante___2.jpg
# R_19_51-36-06-18_OP4_21PhotoEtatsante___2.xml
# R_1_98-44-83-87_OP4_21PhotoEtatsante___3.jpg
# R_1_98-44-83-87_OP4_21PhotoEtatsante___3.xml
# R_19_86-85-01-51_OP4_21PhotoEtatsante___2.jpg
# R_19_86-85-01-51_OP4_21PhotoEtatsante___2.xml
# R_20_00-85-46-60_OP4_21PhotoEtatsante___1.jpg
# R_20_00-85-46-60_OP4_21PhotoEtatsante___1.xml
# R_20_02-97-75-30_OP4_21PhotoEtatsante___2.jpg
# R_20_02-97-75-30_OP4_21PhotoEtatsante___2.xml
# R_20_17-11-71-77_OP4_21PhotoEtatsante___4.jpg
# R_20_17-11-71-77_OP4_21PhotoEtatsante___4.xml
# R_20_19-06-03-29_OP4_21PhotoEtatsante___3.jpg
# R_20_19-06-03-29_OP4_21PhotoEtatsante___3.xml
# R_20_30-03-27-88_OP4_15PhotoEltParcel__.jpg
# R_20_30-03-27-88_OP4_15PhotoEltParcel__.xml
# R_20_30-06-22-07_OP4_21PhotoEtatsante___3.jpg
# R_20_30-06-22-07_OP4_21PhotoEtatsante___3.xml
# R_20_31-22-85-36_OP4_21PhotoEtatsante___5.jpg
# R_20_31-22-85-36_OP4_21PhotoEtatsante___5.xml
# R_20_31-86-14-66_OP4_21PhotoEtatsante___2.jpg
# R_20_31-86-14-66_OP4_21PhotoEtatsante___2.xml
# R_20_41-14-79-69_OP4_21PhotoEtatsante___2.jpg
# R_20_41-14-79-69_OP4_21PhotoEtatsante___2.xml
# R_20_45-86-29-39_OP4_21PhotoEtatsante___1.jpg
# R_20_45-86-29-39_OP4_21PhotoEtatsante___1.xml
# R_20_48-96-50-59_OP4_21PhotoEtatsante___2.jpg
# R_20_48-96-50-59_OP4_21PhotoEtatsante___2.xml
# R_20_52-05-65-49_OP4_21PhotoEtatsante___5.jpg
# R_20_52-05-65-49_OP4_21PhotoEtatsante___5.xml
# R_20_62-40-22-75_OP4_21PhotoEtatsante___3.jpg
# R_20_62-40-22-75_OP4_21PhotoEtatsante___3.xml
# R_20_70-74-24-82_OP4_21PhotoEtatsante___1.jpg
# R_20_70-74-24-82_OP4_21PhotoEtatsante___1.xml
# R_20_71-04-45-31_OP4_21PhotoEtatsante___5.jpg
# R_20_71-04-45-31_OP4_21PhotoEtatsante___5.xml
# R_20_76-83-62-34_OP4_21PhotoEtatsante___2.jpg
# R_20_76-83-62-34_OP4_21PhotoEtatsante___2.xml
# R_20_91-83-32-01_OP4_21PhotoEtatsante___1.jpg
# R_20_91-83-32-01_OP4_21PhotoEtatsante___1.xml
# R_20_94-33-87-39_OP4_21PhotoEtatsante___5.jpg
# R_20_94-33-87-39_OP4_21PhotoEtatsante___5.xml
# R_20_95-37-27-00_OP4_21PhotoEtatsante___4.jpg
# R_20_95-37-27-00_OP4_21PhotoEtatsante___4.xml
# R_21_40-01-48-02_OP4_21PhotoEtatsante___1.jpg
# R_21_40-01-48-02_OP4_21PhotoEtatsante___1.xml
# R_2_15-19-44-92_OP4_21PhotoEtatsante___2.jpg
# R_2_15-19-44-92_OP4_21PhotoEtatsante___2.xml
# R_2_15-19-44-92_OP4_21PhotoEtatsante___5.jpg
# R_2_15-19-44-92_OP4_21PhotoEtatsante___5.xml
# R_21_60-64-75-91_OP4_21PhotoEtatsante___1.jpg
# R_21_60-64-75-91_OP4_21PhotoEtatsante___1.xml
# R_21_62-09-44-67_OP4_21PhotoEtatsante___3.jpg
# R_21_62-09-44-67_OP4_21PhotoEtatsante___3.xml
# R_21_79-97-86-30_OP4_21PhotoEtatsante___5.jpg
# R_21_79-97-86-30_OP4_21PhotoEtatsante___5.xml
# R_2_50-16-62-59_OP4_21PhotoEtatsante___4.jpg
# R_2_50-16-62-59_OP4_21PhotoEtatsante___4.xml
# R_2_50-16-62-59_OP4_21PhotoEtatsante___5.jpg
# R_2_50-16-62-59_OP4_21PhotoEtatsante___5.xml
# R_3_00-30-70-37_OP4_21PhotoEtatsante___3.jpg
# R_3_00-30-70-37_OP4_21PhotoEtatsante___3.xml
# R_3_00-30-70-37_OP4_21PhotoEtatsante___4.jpg
# R_3_00-30-70-37_OP4_21PhotoEtatsante___4.xml
# R_3_04-22-54-85_OP4_21PhotoEtatsante___2.jpg
# R_3_04-22-54-85_OP4_21PhotoEtatsante___2.xml
# R_3_10-55-64-11_OP4_21PhotoEtatsante___4.jpg
# R_3_10-55-64-11_OP4_21PhotoEtatsante___4.xml
# R_3_10-55-64-11_OP4_21PhotoEtatsante___5.jpg
# R_3_10-55-64-11_OP4_21PhotoEtatsante___5.xml
# R_3_40-01-61-10_OP4_21PhotoEtatsante___3.jpg
# R_3_40-01-61-10_OP4_21PhotoEtatsante___3.xml
# R_3_65-39-90-01_OP4_21PhotoEtatsante___3.jpg
# R_3_65-39-90-01_OP4_21PhotoEtatsante___3.xml
# R_3_68-46-92-07_OP4_21PhotoEtatsante___3.jpg
# R_3_68-46-92-07_OP4_21PhotoEtatsante___3.xml
# R_3_78-83-76-63_OP4_21PhotoEtatsante___2.jpg
# R_3_78-83-76-63_OP4_21PhotoEtatsante___2.xml
# R_3_83-33-49-13_OP4_21PhotoEtatsante___2.jpg
# R_3_83-33-49-13_OP4_21PhotoEtatsante___2.xml
# R_3_91-52-38-64_OP4_21PhotoEtatsante___4.jpg
# R_3_91-52-38-64_OP4_21PhotoEtatsante___4.xml
# R_4_14-60-16-14_OP4_21PhotoEtatsante___1.jpg
# R_4_14-60-16-14_OP4_21PhotoEtatsante___1.xml
# R_4_35-24-45-43_OP4_19PhotoEtatSante__.jpg
# R_4_35-24-45-43_OP4_19PhotoEtatSante__.xml
# R_4_36-05-15-84_OP4_21PhotoEtatsante___5.jpg
# R_4_36-05-15-84_OP4_21PhotoEtatsante___5.xml
# R_4_87-55-51-78_OP4_21PhotoEtatsante___3.jpg
# R_4_87-55-51-78_OP4_21PhotoEtatsante___3.xml
# R_4_90-44-28-23_OP4_21PhotoEtatsante___5.jpg
# R_4_90-44-28-23_OP4_21PhotoEtatsante___5.xml
# R_5_06-84-73-84_OP4_11PhotoDegat__.jpg
# R_5_06-84-73-84_OP4_11PhotoDegat__.xml
# R_5_25-74-36-29_OP4_21PhotoEtatsante___3.jpg
# R_5_25-74-36-29_OP4_21PhotoEtatsante___3.xml
# R_5_41-80-90-86_OP4_21PhotoEtatsante___1.jpg
# R_5_41-80-90-86_OP4_21PhotoEtatsante___1.xml
# R_5_42-12-60-81_OP4_21PhotoEtatsante___5.jpg
# R_5_42-12-60-81_OP4_21PhotoEtatsante___5.xml
# R_5_52-82-53-46_OP4_21PhotoEtatsante___3.jpg
# R_5_52-82-53-46_OP4_21PhotoEtatsante___3.xml
# R_5_56-06-61-07_OP4_21PhotoEtatsante___2.jpg
# R_5_56-06-61-07_OP4_21PhotoEtatsante___2.xml
# R_5_65-61-07-98_OP4_21PhotoEtatsante___3.jpg
# R_5_65-61-07-98_OP4_21PhotoEtatsante___3.xml
# R_5_69-76-46-86_OP4_21PhotoEtatsante___3.jpg
# R_5_69-76-46-86_OP4_21PhotoEtatsante___3.xml
# R_5_72-30-91-38_OP4_21PhotoEtatsante___4.jpg
# R_5_72-30-91-38_OP4_21PhotoEtatsante___4.xml
# R_5_75-79-54-59_OP4_21PhotoEtatsante___1.jpg
# R_5_75-79-54-59_OP4_21PhotoEtatsante___1.xml
# R_5_82-11-61-58_OP4_21PhotoEtatsante___2.jpg
# R_5_82-11-61-58_OP4_21PhotoEtatsante___2.xml
# R_5_82-35-33-16_OP4_21PhotoEtatsante___2.jpg
# R_5_82-35-33-16_OP4_21PhotoEtatsante___2.xml
# R_5_83-52-85-98_OP4_21PhotoEtatsante___4.jpg
# R_5_83-52-85-98_OP4_21PhotoEtatsante___4.xml
# R_6_04-83-30-32_OP4_21PhotoEtatsante___3.jpg
# R_6_04-83-30-32_OP4_21PhotoEtatsante___3.xml
# R_6_09-09-36-99_OP4_21PhotoEtatsante___2.jpg
# R_6_09-09-36-99_OP4_21PhotoEtatsante___2.xml
# R_6_09-09-36-99_OP4_21PhotoEtatsante___5.jpg
# R_6_09-09-36-99_OP4_21PhotoEtatsante___5.xml
# R_6_14-59-68-15_OP4_21PhotoEtatsante___1.jpg
# R_6_14-59-68-15_OP4_21PhotoEtatsante___1.xml
# R_6_21-70-90-95_OP4_21PhotoEtatsante___4.jpg
# R_6_21-70-90-95_OP4_21PhotoEtatsante___4.xml
# R_6_23-08-94-43_OP4_21PhotoEtatsante___4.jpg
# R_6_23-08-94-43_OP4_21PhotoEtatsante___4.xml
# R_6_37-65-17-66_OP4_21PhotoEtatsante___5.jpg
# R_6_37-65-17-66_OP4_21PhotoEtatsante___5.xml
# R_6_51-22-94-09_OP4_21PhotoEtatsante___3.jpg
# R_6_51-22-94-09_OP4_21PhotoEtatsante___3.xml
# R_6_53-07-19-79_OP4_21PhotoEtatsante___1.jpg
# R_6_53-07-19-79_OP4_21PhotoEtatsante___1.xml
# R_6_54-03-97-48_OP4_21PhotoEtatsante___2.jpg
# R_6_54-03-97-48_OP4_21PhotoEtatsante___2.xml
# R_6_58-59-90-50_OP4_21PhotoEtatsante___4.jpg
# R_6_58-59-90-50_OP4_21PhotoEtatsante___4.xml
# R_6_58-73-99-13_OP4_21PhotoEtatsante___5.jpg
# R_6_58-73-99-13_OP4_21PhotoEtatsante___5.xml
# R_6_72-21-61-22_OP4_21PhotoEtatsante___5.jpg
# R_6_72-21-61-22_OP4_21PhotoEtatsante___5.xml
# R_6_72-55-22-49_OP4_21PhotoEtatsante___2.jpg
# R_6_72-55-22-49_OP4_21PhotoEtatsante___2.xml
# R_6_73-34-52-92_OP4_21PhotoEtatsante___2.jpg
# R_6_73-34-52-92_OP4_21PhotoEtatsante___2.xml
# R_6_98-29-50-91_OP4_21PhotoEtatsante___1.jpg
# R_6_98-29-50-91_OP4_21PhotoEtatsante___1.xml
# R_7_10-65-13-54_OP4_21PhotoEtatsante___3.jpg
# R_7_10-65-13-54_OP4_21PhotoEtatsante___3.xml
# R_7_10-65-13-54_OP4_21PhotoEtatsante___4.jpg
# R_7_10-65-13-54_OP4_21PhotoEtatsante___4.xml
# R_7_36-68-26-21_OP4_21PhotoEtatsante___2.jpg
# R_7_36-68-26-21_OP4_21PhotoEtatsante___2.xml
# R_7_42-74-35-59_OP4_21PhotoEtatsante___3.jpg
# R_7_42-74-35-59_OP4_21PhotoEtatsante___3.xml
# R_7_50-55-44-74_OP4_21PhotoEtatsante___3.jpg
# R_7_50-55-44-74_OP4_21PhotoEtatsante___3.xml
# R_7_62-29-10-52_OP4_21PhotoEtatsante___1.jpg
# R_7_62-29-10-52_OP4_21PhotoEtatsante___1.xml
# R_7_63-46-89-18_OP4_21PhotoEtatsante___4.jpg
# R_7_63-46-89-18_OP4_21PhotoEtatsante___4.xml
# R_7_79-63-16-22_OP4_21PhotoEtatsante___3.jpg
# R_7_79-63-16-22_OP4_21PhotoEtatsante___3.xml
# R_7_82-96-06-62_OP4_21PhotoEtatsante___4.jpg
# R_7_82-96-06-62_OP4_21PhotoEtatsante___4.xml
# R_7_93-92-48-84_OP4_21PhotoEtatsante___1.jpg
# R_7_93-92-48-84_OP4_21PhotoEtatsante___1.xml
# R_7_93-92-48-84_OP4_21PhotoEtatsante___3.jpg
# R_7_93-92-48-84_OP4_21PhotoEtatsante___3.xml
# R_8_05-43-67-38_OP4_21PhotoEtatsante___1.jpg
# R_8_05-43-67-38_OP4_21PhotoEtatsante___1.xml
# R_8_09-96-13-65_OP4_21PhotoEtatsante___3.jpg
# R_8_09-96-13-65_OP4_21PhotoEtatsante___3.xml
# R_8_11-70-36-68_OP4_21PhotoEtatsante___3.jpg
# R_8_11-70-36-68_OP4_21PhotoEtatsante___3.xml
# R_8_14-75-14-33_OP4_21PhotoEtatsante___2.jpg
# R_8_14-75-14-33_OP4_21PhotoEtatsante___2.xml
# R_8_17-63-29-67_OP4_21PhotoEtatsante___2.jpg
# R_8_17-63-29-67_OP4_21PhotoEtatsante___2.xml
# R_8_44-69-76-13_OP4_21PhotoEtatsante___1.jpg
# R_8_44-69-76-13_OP4_21PhotoEtatsante___1.xml
# R_8_49-62-24-94_OP4_21PhotoEtatsante___5.jpg
# R_8_49-62-24-94_OP4_21PhotoEtatsante___5.xml
# R_8_63-58-61-53_OP4_21PhotoEtatsante___1.jpg
# R_8_63-58-61-53_OP4_21PhotoEtatsante___1.xml
# R_8_88-52-38-03_OP4_11PhotoDegat__.jpg
# R_8_88-52-38-03_OP4_11PhotoDegat__.xml
# R_8_88-85-49-86_OP4_21PhotoEtatsante___2.jpg
# R_8_88-85-49-86_OP4_21PhotoEtatsante___2.xml
# R_8_93-23-46-31_OP4_21PhotoEtatsante___3.jpg
# R_8_93-23-46-31_OP4_21PhotoEtatsante___3.xml

# %%
# NOTE: Update these TFRecord names from "cells" and "cells_label_map" to your files!
test_record_fname = '/content/Cashew_images/data2/FEUILLES/train.record'
train_record_fname = '/content/Cashew_images/data2/FEUILLES/test.record'
label_map_pbtxt_fname = '/content/Cashew_images/labelmap/cashew_label_map.pbtxt'

# %% [markdown]
# ## Téléchargement du Modèle de Base

# %%
# %cd /content/models/research

import os
import shutil
import glob
import urllib.request
import tarfile
MODEL_FILE = MODEL + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'
DEST_DIR = '/content/models/research/pretrained_model'

if not (os.path.exists(MODEL_FILE)):
    urllib.request.urlretrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
    shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)
# Out:
# /content/models/research

# %%
# !echo {DEST_DIR}
# !ls -alh {DEST_DIR}
# Out:
# /content/models/research/pretrained_model
# total 135M
# drwxr-xr-x  3 345018 89939 4.0K Mar 30  2018 .
# drwxr-xr-x 24 root   root  4.0K Mar  8 10:14 ..
# -rw-r--r--  1 345018 89939   77 Mar 30  2018 checkpoint
# -rw-r--r--  1 345018 89939  67M Mar 30  2018 frozen_inference_graph.pb
# -rw-r--r--  1 345018 89939  65M Mar 30  2018 model.ckpt.data-00000-of-00001
# -rw-r--r--  1 345018 89939  15K Mar 30  2018 model.ckpt.index
# -rw-r--r--  1 345018 89939 3.4M Mar 30  2018 model.ckpt.meta
# -rw-r--r--  1 345018 89939 4.2K Mar 30  2018 pipeline.config
# drwxr-xr-x  3 345018 89939 4.0K Mar 30  2018 saved_model

# %%
fine_tune_checkpoint = os.path.join(DEST_DIR, "model.ckpt")
fine_tune_checkpoint
# Out:
# '/content/models/research/pretrained_model/model.ckpt'

# %% [markdown]
# ## Configuring a Training Pipeline

# %%
import os
pipeline_fname = os.path.join('/content/models/research/object_detection/samples/configs/', pipeline_file)

assert os.path.isfile(pipeline_fname), '`{}` not exist'.format(pipeline_fname)

# %%
def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())

# %%
import re

num_classes = get_num_classes(label_map_pbtxt_fname)
with open(pipeline_fname) as f:
    s = f.read()
with open(pipeline_fname, 'w') as f:
    
    # fine_tune_checkpoint
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)
    
    # tfrecord files train and test.
    s = re.sub(
        '(input_path: ".*?)(train.record)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(val.record)(.*?")', 'input_path: "{}"'.format(test_record_fname), s)

    # label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set training batch_size.
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)
    
    # Set number of classes num_classes.
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)
    f.write(s)

# %%
# !cat {pipeline_fname}
# Out:
# # SSD with Mobilenet v2 configuration for MSCOCO Dataset.
# # Users should configure the fine_tune_checkpoint field in the train config as
# # well as the label_map_path and input_path fields in the train_input_reader and
# # eval_input_reader. Search for "PATH_TO_BE_CONFIGURED" to find the fields that
# # should be configured.
#
# model {
#   ssd {
#     num_classes: 12
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     anchor_generator {
#       ssd_anchor_generator {
#         num_layers: 6
#         min_scale: 0.2
#         max_scale: 0.95
#         aspect_ratios: 1.0
#         aspect_ratios: 2.0
#         aspect_ratios: 0.5
#         aspect_ratios: 3.0
#         aspect_ratios: 0.3333
#       }
#     }
#     image_resizer {
#       fixed_shape_resizer {
#         height: 300
#         width: 300
#       }
#     }
#     box_predictor {
#       convolutional_box_predictor {
#         min_depth: 0
#         max_depth: 0
#         num_layers_before_predictor: 0
#         use_dropout: false
#         dropout_keep_probability: 0.8
#         kernel_size: 1
#         box_code_size: 4
#         apply_sigmoid_to_scores: false
#         conv_hyperparams {
#           activation: RELU_6,
#           regularizer {
#             l2_regularizer {
#               weight: 0.00004
#             }
#           }
#           initializer {
#             truncated_normal_initializer {
#               stddev: 0.03
#               mean: 0.0
#             }
#           }
#           batch_norm {
#             train: true,
#             scale: true,
#             center: true,
#             decay: 0.9997,
#             epsilon: 0.001,
#           }
#         }
#       }
#     }
#     feature_extractor {
#       type: 'ssd_mobilenet_v2'
#       min_depth: 16
#       depth_multiplier: 1.0
#       conv_hyperparams {
#         activation: RELU_6,
#         regularizer {
#           l2_regularizer {
#             weight: 0.00004
#           }
#         }
#         initializer {
#           truncated_normal_initializer {
#             stddev: 0.03
#             mean: 0.0
#           }
#         }
#         batch_norm {
#           train: true,
#           scale: true,
#           center: true,
#           decay: 0.9997,
#           epsilon: 0.001,
#         }
#       }
#     }
#     loss {
#       classification_loss {
#         weighted_sigmoid {
#         }
#       }
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       hard_example_miner {
#         num_hard_examples: 3000
#         iou_threshold: 0.99
#         loss_type: CLASSIFICATION
#         max_negatives_per_positive: 3
#         min_negatives_per_image: 3
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     normalize_loss_by_num_matches: true
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 1e-8
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 100
#       }
#       score_converter: SIGMOID
#     }
#   }
# }
#
# train_config: {
#   batch_size: 12
#   optimizer {
#     rms_prop_optimizer: {
#       learning_rate: {
#         exponential_decay_learning_rate {
#           initial_learning_rate: 0.004
#           decay_steps: 800720
#           decay_factor: 0.95
#         }
#       }
#       momentum_optimizer_value: 0.9
#       decay: 0.9
#       epsilon: 1.0
#     }
#   }
#   fine_tune_checkpoint: "/content/models/research/pretrained_model/model.ckpt"
#   fine_tune_checkpoint_type:  "detection"
#   # Note: The below line limits the training process to 200K steps, which we
#   # empirically found to be sufficient enough to train the pets dataset. This
#   # effectively bypasses the learning rate schedule (the learning rate will
#   # never decay). Remove the below line to train indefinitely.
#   num_steps: 20000
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     ssd_random_crop {
#     }
#   }
# }
#
# train_input_reader: {
#   tf_record_input_reader {
#     input_path: "/content/Cashew_images/data2/FEUILLES/test.record"
#   }
#   label_map_path: "/content/Cashew_images/labelmap/cashew_label_map.pbtxt"
# }
#
# eval_config: {
#   num_examples: 8000
#   # Note: The below line limits the evaluation process to 10 evaluations.
#   # Remove the below line to evaluate indefinitely.
#   max_evals: 10
# }
#
# eval_input_reader: {
#   tf_record_input_reader {
#     input_path: "/content/Cashew_images/data2/FEUILLES/train.record"
#   }
#   label_map_path: "/content/Cashew_images/labelmap/cashew_label_map.pbtxt"
#   shuffle: false
#   num_readers: 1
# }

# %%
model_dir = '/content/drive/MyDrive/training'
# Optionally remove content in output model directory to fresh start.
# !rm -rf {model_dir}
os.makedirs(model_dir, exist_ok=True)

# %% [markdown]
# ## Configuring CUDA on Colab

# %%
# CUDA: Let's check that Nvidia CUDA drivers are already pre-installed and which version is it. This can be helpful for debugging.
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %% [markdown]
# **IMPORTANT!** If you're not training on a Tesla P100 GPU, we will need to tweak our Darknet configuration later based on what type of GPU we have. Let's set that now while we're inspecting the GPU.

# %%
#take a look at the kind of GPU we have
# !nvidia-smi
# Out:
# Mon Mar  8 10:14:53 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Change the number depending on what GPU is listed above, under NVIDIA-SMI > Name.
# Tesla K80: 30
# Tesla P100: 60
# Tesla T4: 75
# %env compute_capability=60
# Out:
# env: compute_capability=60

# %% [markdown]
# ## Run Tensorboard(Optional)

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip
# Out:
# --2021-03-08 10:14:54--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.1.26.21, 54.159.34.239, 3.228.103.136, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.1.26.21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  65.5MB/s    in 0.2s
#
# 2021-03-08 10:14:54 (65.5 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
LOG_DIR = model_dir
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %% [markdown]
# ### Get Tensorboard link

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# IndexError: list index out of range

# %%
# !pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.12.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)

# %% [markdown]
# ## Train the model

# %%
# !python /content/models/research/object_detection/model_main.py \
    --pipeline_config_path={pipeline_fname} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --num_eval_steps={num_eval_steps}
# Out:
# Streaming output truncated to the last 5000 lines.
# W0308 13:36:48.326909 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c621910>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c621910>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c7dac90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c7dac90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.395754 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c7dac90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c7dac90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c4c3510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c4c3510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.422364 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c4c3510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c4c3510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c4c8990>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c4c8990>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.458556 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c4c8990>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c4c8990>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c6b2190>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c6b2190>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.543585 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c6b2190>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c6b2190>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c432490>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c432490>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.574183 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c432490>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c432490>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c432710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c432710>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.639264 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c432710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c432710>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c225f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c225f10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.667168 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c225f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c225f10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c36a2d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c36a2d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.708708 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c36a2d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c36a2d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c432710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c432710>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.772119 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c432710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c432710>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c36a6d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c36a6d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.808523 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c36a6d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c36a6d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c1b76d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c1b76d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.880250 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c1b76d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c1b76d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bfec350>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bfec350>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.907086 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bfec350>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bfec350>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bfeca10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bfeca10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:48.942374 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bfeca10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bfeca10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2777d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2777d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.002882 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2777d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2777d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c046450>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c046450>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.029164 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c046450>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64c046450>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bf9b450>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bf9b450>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.091292 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bf9b450>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bf9b450>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bdabd10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bdabd10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.131803 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bdabd10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bdabd10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bddcc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bddcc50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.175119 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bddcc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bddcc50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bfecd50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bfecd50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.237686 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bfecd50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bfecd50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bbcd490>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bbcd490>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.264287 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bbcd490>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bbcd490>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64d367fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64d367fd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.330011 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64d367fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64d367fd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb6cc10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb6cc10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.360485 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb6cc10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb6cc10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb20b10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb20b10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.405698 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb20b10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb20b10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2a7050>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2a7050>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.480883 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2a7050>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2a7050>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb20e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb20e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.509372 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb20e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64bb20e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bb0f790>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bb0f790>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.573014 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bb0f790>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bb0f790>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b987490>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b987490>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.600462 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b987490>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b987490>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b9f1fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b9f1fd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.637440 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b9f1fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b9f1fd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bb0f750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bb0f750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.706394 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bb0f750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64bb0f750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b8d0110>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b8d0110>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.745291 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b8d0110>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b8d0110>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64ba1f910>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64ba1f910>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.814405 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64ba1f910>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64ba1f910>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b883ad0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b883ad0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.842687 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b883ad0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b883ad0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b8835d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b8835d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.879611 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b8835d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b8835d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64ba3ed90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64ba3ed90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.940390 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64ba3ed90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64ba3ed90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b733ed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b733ed0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:49.969027 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b733ed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b733ed0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2a7310>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2a7310>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:50.053954 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2a7310>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64c2a7310>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b924590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b924590>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:50.088296 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b924590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b924590>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc6522dac50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc6522dac50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:50.156684 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc6522dac50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc6522dac50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b682ed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b682ed0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:50.183052 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b682ed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b682ed0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64b987050>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64b987050>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:50.242587 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64b987050>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64b987050>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b7370d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b7370d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 13:36:50.269078 140491490486144 ag_logging.py:145] Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b7370d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fc64b7370d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc6522eb1d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc6522eb1d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# ...
# W0308 16:17:43.408334 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9050>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9050>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae93d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae93d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 16:17:43.493684 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae93d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae93d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0308 16:17:43.497097 140491490486144 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9150>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9150>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 16:17:43.562031 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9150>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9150>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9990>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9990>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 16:17:43.629422 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9990>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9990>>: AssertionError: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0308 16:17:43.632550 140491490486144 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9f50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9f50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 16:17:43.710284 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9f50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9f50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aadef50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aadef50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 16:17:43.788535 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aadef50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aadef50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0308 16:17:43.791606 140491490486144 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae95d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae95d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 16:17:43.854436 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae95d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae95d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9150>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9150>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 16:17:43.938366 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9150>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aae9150>>: AssertionError: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0308 16:17:43.943115 140491490486144 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aaee8d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aaee8d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 16:17:44.014205 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aaee8d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aaee8d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aaee4d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aaee4d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# W0308 16:17:44.086132 140491490486144 ag_logging.py:145] Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aaee4d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x7fc64aaee4d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Done calling model_fn.
# I0308 16:17:46.514817 140491490486144 estimator.py:1147] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-03-08T16:17:46Z
# I0308 16:17:46.532868 140491490486144 evaluation.py:255] Starting evaluation at 2021-03-08T16:17:46Z
# INFO:tensorflow:Graph was finalized.
# I0308 16:17:46.964399 140491490486144 monitored_session.py:240] Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/training/model.ckpt-3266
# I0308 16:17:46.967448 140491490486144 saver.py:1280] Restoring parameters from /content/drive/MyDrive/training/model.ckpt-3266
# INFO:tensorflow:Running local_init_op.
# I0308 16:17:47.743098 140491490486144 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0308 16:17:47.863518 140491490486144 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 179 images.
# I0308 16:18:21.288448 140489867093760 coco_evaluation.py:293] Performing evaluation on 179 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0308 16:18:21.290185 140489867093760 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.01s)
# I0308 16:18:21.301960 140489867093760 coco_tools.py:138] DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.34s).
# Accumulating evaluation results...
# DONE (t=0.38s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
# INFO:tensorflow:Finished evaluation at 2021-03-08-16:18:24
# I0308 16:18:24.323531 140491490486144 evaluation.py:275] Finished evaluation at 2021-03-08-16:18:24
# INFO:tensorflow:Saving dict for global step 3266: DetectionBoxes_Precision/mAP = 6.1172072e-06, DetectionBoxes_Precision/mAP (large) = 7.877784e-06, DetectionBoxes_Precision/mAP (medium) = 0.0, DetectionBoxes_Precision/mAP (small) = 0.0, DetectionBoxes_Precision/mAP@.50IOU = 1.4213971e-05, DetectionBoxes_Precision/mAP@.75IOU = 0.0, DetectionBoxes_Recall/AR@1 = 0.0, DetectionBoxes_Recall/AR@10 = 0.0016889691, DetectionBoxes_Recall/AR@100 = 0.0019739526, DetectionBoxes_Recall/AR@100 (large) = 0.002664179, DetectionBoxes_Recall/AR@100 (medium) = 0.0, DetectionBoxes_Recall/AR@100 (small) = 0.0, Loss/classification_loss = 14.227748, Loss/localization_loss = 3.2199943, Loss/regularization_loss = 0.3232229, Loss/total_loss = 17.770964, global_step = 3266, learning_rate = 0.004, loss = 17.770964
# I0308 16:18:24.323815 140491490486144 estimator.py:2039] Saving dict for global step 3266: DetectionBoxes_Precision/mAP = 6.1172072e-06, DetectionBoxes_Precision/mAP (large) = 7.877784e-06, DetectionBoxes_Precision/mAP (medium) = 0.0, DetectionBoxes_Precision/mAP (small) = 0.0, DetectionBoxes_Precision/mAP@.50IOU = 1.4213971e-05, DetectionBoxes_Precision/mAP@.75IOU = 0.0, DetectionBoxes_Recall/AR@1 = 0.0, DetectionBoxes_Recall/AR@10 = 0.0016889691, DetectionBoxes_Recall/AR@100 = 0.0019739526, DetectionBoxes_Recall/AR@100 (large) = 0.002664179, DetectionBoxes_Recall/AR@100 (medium) = 0.0, DetectionBoxes_Recall/AR@100 (small) = 0.0, Loss/classification_loss = 14.227748, Loss/localization_loss = 3.2199943, Loss/regularization_loss = 0.3232229, Loss/total_loss = 17.770964, global_step = 3266, learning_rate = 0.004, loss = 17.770964
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3266: /content/drive/MyDrive/training/model.ckpt-3266
# I0308 16:18:24.334853 140491490486144 estimator.py:2099] Saving 'checkpoint_path' summary for global step 3266: /content/drive/MyDrive/training/model.ckpt-3266
# INFO:tensorflow:global_step/sec: 0.152853
# I0308 16:21:56.055344 140491490486144 basic_session_run_hooks.py:692] global_step/sec: 0.152853
# INFO:tensorflow:loss = 6.5706186, step = 3301 (654.225 sec)
# I0308 16:21:56.057030 140491490486144 basic_session_run_hooks.py:260] loss = 6.5706186, step = 3301 (654.225 sec)

# %%
# !ls {model_dir}
# Out:
# ls: cannot access '{model_dir}': No such file or directory

# %% [markdown]
# ## Exporting a Trained Inference Graph

# %%
import re
import numpy as np

output_directory = '/content/drive/MyDrive'

lst = os.listdir(model_dir)
lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
last_model = lst[steps.argmax()].replace('.meta', '')

last_model_path = os.path.join(model_dir, last_model)
print(last_model_path)
# !python /content/models/research/object_detection/export_inference_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path={pipeline_fname} \
    --output_directory={output_directory} \
    --trained_checkpoint_prefix={last_model_path}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6305f42d94d6> in <module>()
#       4 output_directory = '/content/drive/MyDrive'
#       5
# ----> 6 lst = os.listdir(model_dir)
#       7 lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
#       8 steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
#
# NameError: name 'os' is not defined

# %%
# !ls {output_directory}

# %% [markdown]
# ## Exporter en TFLITE

# %%
# Exporter en tflite.pb
# !mkdir '/content/tflite'
# !python /content/models/research/object_detection/export_tflite_ssd_graph.py --pipeline_config_path={pipeline_fname} --trained_checkpoint_prefix={last_model_path} --output_directory='/content/tflite' --add_postprocessing_op=true

# %%
# Exporter le TFLite.pb en model.tflite
import tensorflow as tf
input_arrays = ["normalized_input_image_tensor"]
output_arrays = ["TFLite_Detection_PostProcess","TFLite_Detection_PostProcess:1","TFLite_Detection_PostProcess:2","TFLite_Detection_PostProcess:3"]
input_shapes = {"normalized_input_image_tensor" : [1, 300, 300, 3]}
converter = tf.lite.TFLiteConverter.from_frozen_graph(
        '/content/tflite/tflite_graph.pb', input_arrays, output_arrays, input_shapes)
converter.allow_custom_ops = True
converter.quantized_input_stats = {"normalized_input_image_tensor": (128., 127.)}
tflite_model = converter.convert()
open("/content/ssd.tflite", "wb").write(tflite_model)
